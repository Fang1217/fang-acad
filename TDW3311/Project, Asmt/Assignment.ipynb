# %% [markdown]
# # TDW 3311 Lab Assignment
#
# ### Group Name: TechTitans
# #### Group Members:
# - LIM FANG WEI (1211306646)
# - HOW SHUE KEI (1201103432)
# - KOW WAN XUAN (1211307650)
# - HO JUN WEI (1211306530)

# %% [markdown]
# ##  Part 1- Data Cleaning and Transformation (20 Marks)
#
# You will be working with a dataset containing various data quality issues, such as missing data, outliers, unstructured data, and more. Your task is to clean, preprocess, and transform the data to make it suitable for visualisation or further analysis and modeling. Please perform the following tasks using <u>Dataset1</u>

# %%
#Dataset read

import pandas as pd
import numpy as np

df1 = pd.read_csv('Dataset1.csv', header = 0)
display(df1.head())
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %% [markdown]
# #### 1.1 Missing Data Handling (3 Marks)
# - Identify the columns with missing values and decide on an appropriate strategy to handle them.

# %%
#Identify columns with missing values
print(f"Number of missing values before dropping missing data:\n{df1.isnull().sum()}\n")
# Out:
# Number of missing values before dropping missing data:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
#Check rows with NA values.
display(df1[df1.isna().any(axis=1)])
# Out:
#              id                                               name   host_id  \
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 19         7750                  Huge 2 BR Upper East  Cental Park     17985
# 26         8700  Magnifique Suite au N de Manhattan - vue Cloitres     26394
# 36        11452                        Clean and Quiet in Brooklyn      7355
# 38        11943                          Country space in the city     45445
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#              host_name neighbourhood_group       neighbourhood  latitude  \
# 2            Elisabeth           Manhattan              Harlem  40.80902
# 19                Sing           Manhattan         East Harlem  40.79685
# 26     Claude & Sophie           Manhattan              Inwood  40.86754
# 36                  Vt            Brooklyn  Bedford-Stuyvesant  40.68876
# 38             Harriet            Brooklyn            Flatbush  40.63702
# ...                ...                 ...                 ...       ...
# 48890          Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891          Marisol            Brooklyn            Bushwick  40.70184
# 48892    Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893              Taz           Manhattan      Hell's Kitchen  40.75751
# 48894       Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 2      -73.94190     Private room    150               3                  0
# 19     -73.94872  Entire home/apt    190               7                  0
# 26     -73.92639     Private room     80               4                  0
# 36     -73.94312     Private room     35              60                  0
# 38     -73.96327     Private room    150               1                  0
# ...          ...              ...    ...             ...                ...
# 48890  -73.94995     Private room     70               2                  0
# 48891  -73.93317     Private room     40               4                  0
# 48892  -73.94867  Entire home/apt    115              10                  0
# 48893  -73.99112      Shared room     55               1                  0
# 48894  -73.98933     Private room     90               7                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 2             NaN                NaN                               1
# 19            NaN                NaN                               2
# 26            NaN                NaN                               1
# 36            NaN                NaN                               1
# 38            NaN                NaN                               1
# ...           ...                ...                             ...
# 48890         NaN                NaN                               2
# 48891         NaN                NaN                               2
# 48892         NaN                NaN                               1
# 48893         NaN                NaN                               6
# 48894         NaN                NaN                               1
#
#        availability_365
# 2                   365
# 19                  249
# 26                    0
# 36                  365
# 38                  365
# ...                 ...
# 48890                 9
# 48891                36
# 48892                27
# 48893                 2
# 48894                23
#
# [10074 rows x 16 columns]

# %% [markdown]
# - Implement the chosen method to fill or drop missing data.

# %%
#Drop the missing data
#Note: There are known to be NaN when number_of_reviews = 0. Hence dropping such rows only if the number_of_reviews is not 0.

df1 = df1.dropna(subset = ['name', 'host_name'])
for i in range(df1.shape[0]):
    if df1.iloc[i]['number_of_reviews'] > 0 and df1.iloc[i]['last_review'] == np.nan:
        df1.iloc[i].drop()

#Check whether the missing data has been dropped successfully or not 
print(f"Number of missing values after dropping missing data:\n{df1.isnull().sum()}")
# Out:
# Number of missing values after dropping missing data:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                 10037
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# #### 1.2 Outliers Detection and Treatment (3 Marks)
#
# - Explore the data to identify potential outliers using box plot, scatter plot and so on.

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import zscore

# %%
#Creating box plot
box_plot = plt.figure(figsize = (20,15))
columns_to_include = [col for col in df1.columns if col not in ['id','host_id']]
sns.boxplot(df1[columns_to_include])

box_plot.show()
# Out:
# C:\Users\Fang\AppData\Local\Temp\ipykernel_11896\5947237.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   box_plot.show()

# %%
#Scatter plot(Minimum Nights vs Price)
exclude_columns=['id','host_id', 'latitude', 'longitude']

df1.plot(kind='scatter', x='minimum_nights',y='price',alpha = .5 )
plt.xlabel('Minimum Nights')
plt.ylabel('Price')
plt.title('Minimum Nights vs Price')

plt.show()

# %%
#scatter plot( only price vs room type)

columns_to_include = [col for col in df1.columns if col not in exclude_columns]
sns.pairplot(df1[columns_to_include])
plt.show()

# %%
#histogram(all)
df1.loc[:, df1.columns.difference(exclude_columns)].hist(figsize=(20,25))
# Out:
# array([[<Axes: title={'center': 'availability_365'}>,
#         <Axes: title={'center': 'calculated_host_listings_count'}>],
#        [<Axes: title={'center': 'minimum_nights'}>,
#         <Axes: title={'center': 'number_of_reviews'}>],
#        [<Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'reviews_per_month'}>]], dtype=object)

# %% [markdown]
# - Decide on an outlier treatment strategy and apply it to the dataset.

# %%
# List outliers which abs z-scores exceeds 3.
df1['Z_price'] = zscore(df1.price)
df1_noOutliers = df1[(abs(df1['Z_price']) <= 3)]
display(df1_noOutliers)
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  ...  number_of_reviews  last_review  \
# 0      -73.97237     Private room    149  ...                  9   2018-10-19
# 1      -73.98377  Entire home/apt    225  ...                 45   2019-05-21
# 2      -73.94190     Private room    150  ...                  0          NaN
# 3      -73.95976  Entire home/apt     89  ...                270   2019-07-05
# 4      -73.94399  Entire home/apt     80  ...                  9   2018-11-19
# ...          ...              ...    ...  ...                ...          ...
# 48890  -73.94995     Private room     70  ...                  0          NaN
# 48891  -73.93317     Private room     40  ...                  0          NaN
# 48892  -73.94867  Entire home/apt    115  ...                  0          NaN
# 48893  -73.99112      Shared room     55  ...                  0          NaN
# 48894  -73.98933     Private room     90  ...                  0          NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0.21                               6               365
# 1                  0.38                               2               355
# 2                   NaN                               1               365
# 3                  4.64                               1               194
# 4                  0.10                               1                 0
# ...                 ...                             ...               ...
# 48890               NaN                               2                 9
# 48891               NaN                               2                36
# 48892               NaN                               1                27
# 48893               NaN                               6                 2
# 48894               NaN                               1                23
#
#         Z_price  Z_minimum_nights  high_demand  revenue    bins
# 0     -0.015570         -0.300329         True      149  budget
# 1      0.300794         -0.300329         True      225  budget
# 2     -0.011407         -0.200426         True      450  budget
# 3     -0.265330         -0.300329        False       89  budget
# 4     -0.302795          0.149232        False      800  budget
# ...         ...               ...          ...      ...     ...
# 48890 -0.344421         -0.250377        False      140  budget
# 48891 -0.469302         -0.150475        False      160  budget
# 48892 -0.157101          0.149232        False     1150  budget
# 48893 -0.406862         -0.300329        False       55  budget
# 48894 -0.261168         -0.000622        False      630  budget
#
# [48470 rows x 21 columns]

# %%
#Show all graphs after removing outlier
exclude_columns = ['id', 'host_id', 'latitude', 'longitude', 'Z_price']
df1_noOutliers.loc[:, df1_noOutliers.columns.difference(exclude_columns)].hist(figsize=(20,25))
# Out:
# array([[<Axes: title={'center': 'Z_minimum_nights'}>,
#         <Axes: title={'center': 'availability_365'}>,
#         <Axes: title={'center': 'calculated_host_listings_count'}>],
#        [<Axes: title={'center': 'minimum_nights'}>,
#         <Axes: title={'center': 'number_of_reviews'}>,
#         <Axes: title={'center': 'price'}>],
#        [<Axes: title={'center': 'revenue'}>,
#         <Axes: title={'center': 'reviews_per_month'}>, <Axes: >]],
#       dtype=object)

# %%
#Creating box plot
box_plot = plt.figure(figsize = (20,15))
columns_to_include = [col for col in df1.columns if col not in exclude_columns]
sns.boxplot(df1_noOutliers[columns_to_include])
box_plot.show()
# Out:
# C:\Users\Fang\AppData\Local\Temp\ipykernel_11896\2375706181.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   box_plot.show()

# %% [markdown]
# #### 1.3 Data Transformation (14 Marks)
# - Select only '`Private room`' listings in '`Manhattan`' neighborhood and save it to `data_sub1`.

# %%
data_sub1 = df1[(df1['neighbourhood_group'] == "Manhattan") & (df1['room_type'] == "Private room")]
data_sub1.head(10)
# Out:
#       id                                               name  host_id  \
# 2   3647                THE VILLAGE OF HARLEM....NEW YORK !     4632
# 7   5178                   Large Furnished Room Near B'way      8967
# 8   5203                 Cozy Clean Guest Room - Family Apt     7490
# 11  5441                    Central Manhattan/near Broadway     7989
# 13  6021   Wonderful Guest Bedroom in Manhattan for SINGLES    11528
# 17  7322                                    Chelsea Perfect    18946
# 26  8700  Magnifique Suite au N de Manhattan - vue Cloitres    26394
# 28  9518       SPACIOUS, LOVELY FURNISHED MANHATTAN BEDROOM    31374
# 30  9668                              front room/double bed    32294
# 31  9704                Spacious 1 bedroom in luxe building    32045
#
#           host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 2         Elisabeth           Manhattan           Harlem  40.80902  -73.94190
# 7          Shunichi           Manhattan   Hell's Kitchen  40.76489  -73.98493
# 8         MaryEllen           Manhattan  Upper West Side  40.80178  -73.96723
# 11             Kate           Manhattan   Hell's Kitchen  40.76076  -73.98867
# 13          Claudio           Manhattan  Upper West Side  40.79826  -73.96113
# 17             Doti           Manhattan          Chelsea  40.74192  -73.99501
# 26  Claude & Sophie           Manhattan           Inwood  40.86754  -73.92639
# 28             Shon           Manhattan           Inwood  40.86482  -73.92106
# 30  Ssameer Or Trip           Manhattan           Harlem  40.82245  -73.95104
# 31             Teri           Manhattan           Harlem  40.81305  -73.95466
#
#        room_type  price  minimum_nights  number_of_reviews last_review  \
# 2   Private room    150               3                  0         NaN
# 7   Private room     79               2                430  2019-06-24
# 8   Private room     79               2                118  2017-07-21
# 11  Private room     85               2                188  2019-06-23
# 13  Private room     85               2                113  2019-07-05
# 17  Private room    140               1                260  2019-07-01
# 26  Private room     80               4                  0         NaN
# 28  Private room     44               3                108  2019-06-15
# 30  Private room     50               3                242  2019-06-01
# 31  Private room     52               2                 88  2019-06-14
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 2                 NaN                               1               365
# 7                3.47                               1               220
# 8                0.99                               1                 0
# 11               1.50                               1                39
# 13               0.91                               1               333
# 17               2.12                               1                12
# 26                NaN                               1                 0
# 28               1.11                               3               311
# 30               2.04                               3               355
# 31               1.42                               1               255
#
#      Z_price  Z_minimum_nights
# 2  -0.011407         -0.200426
# 7  -0.306957         -0.250377
# 8  -0.306957         -0.250377
# 11 -0.281981         -0.250377
# 13 -0.281981         -0.250377
# 17 -0.053034         -0.300329
# 26 -0.302795         -0.150475
# 28 -0.452651         -0.200426
# 30 -0.427675         -0.200426
# 31 -0.419350         -0.250377

# %% [markdown]
# - Filter `data_sub1` to include only listings with 3 minimum number of nights and sort the data according to `Price`.

# %%
data_sub1[data_sub1['minimum_nights'] == 3].sort_values(by=['price'])
# Out:
#              id                                               name    host_id  \
# 28019  21893604            Private Bedroom in West Village/Chelsea    1144452
# 21143  16778904         Quiet cozy apartment, air-conditioned room  111433024
# 11091   8583175            Big Bedroom in Manhattan with an Artist   28272799
# 13775  10368714                                 Martha's Apartment   53369750
# 27033  21394087                              The Hideaway Upstairs  145242566
# ...         ...                                                ...        ...
# 23624  19114014      Large, Private Carriage House in West Village     683230
# 43130  33467371         Private, Beautiful Upper Eastside Townhome     683230
# 20819  16489149  2 BDRM PRESIDENTIAL LUXURY CONDO MIDTOWN 45  N...   69545883
# 20094  16087406  2 BDRM Presidential Reserve at Wyndham Midtown 45   69545883
# 39846  30962126                                       CQ 1 Bedroom   30223355
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 28019     Dante           Manhattan             Chelsea  40.74045  -74.00047
# 21143  Danielle           Manhattan  Washington Heights  40.84353  -73.94201
# 11091      Este           Manhattan              Harlem  40.82855  -73.94033
# 13775    Martha           Manhattan  Washington Heights  40.83790  -73.94095
# 27033     Corey           Manhattan              Harlem  40.81807  -73.95487
# ...         ...                 ...                 ...       ...        ...
# 23624    Thomas           Manhattan        West Village  40.73444  -73.99967
# 43130    Thomas           Manhattan     Upper East Side  40.76725  -73.95864
# 20819    Chayla           Manhattan             Midtown  40.75373  -73.97272
# 20094    Chayla           Manhattan             Midtown  40.75368  -73.97358
# 39846  Adrienne           Manhattan  Financial District  40.70706  -74.00991
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 28019  Private room     12               3                  8  2019-06-07
# 21143  Private room     25               3                 34  2019-05-31
# 11091  Private room     29               3                 27  2018-12-19
# 13775  Private room     30               3                119  2019-06-30
# 27033  Private room     30               3                 86  2019-06-24
# ...             ...    ...             ...                ...         ...
# 23624  Private room    950               3                 36  2019-07-01
# 43130  Private room    950               3                 11  2019-06-30
# 20819  Private room    999               3                  1  2017-09-11
# 20094  Private room   1599               3                  2  2017-06-09
# 39846  Private room   3000               3                  0         NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 28019               0.59                               1                37
# 21143               1.46                               1               139
# 11091               0.59                               1                 0
# 13775               3.19                               1                 3
# 27033               4.32                               2                 0
# ...                  ...                             ...               ...
# 23624               1.45                               3               237
# 43130               4.23                               3               251
# 20819               0.05                              12               365
# 20094               0.08                              12               365
# 39846                NaN                               1                23
#
#          Z_price  Z_minimum_nights
# 28019  -0.585857         -0.200426
# 21143  -0.531742         -0.200426
# 11091  -0.515091         -0.200426
# 13775  -0.510928         -0.200426
# 27033  -0.510928         -0.200426
# ...          ...               ...
# 23624   3.318736         -0.200426
# 43130   3.318736         -0.200426
# 20819   3.522707         -0.200426
# 20094   6.020314         -0.200426
# 39846  11.852227         -0.200426
#
# [1242 rows x 18 columns]

# %% [markdown]
# - Create `data_sub2` where each row represents a unique combination of `neighbourhood_group` and `room_type` with average price for each combination.

# %%
# Create
data_sub2 = df1.groupby(['neighbourhood_group', 'room_type']).agg({'price':'mean'})
display(data_sub2)
# Out:
#                                           price
# neighbourhood_group room_type
# Bronx               Entire home/apt  127.645503
#                     Private room      66.788344
#                     Shared room       58.610169
# Brooklyn            Entire home/apt  178.362609
#                     Private room      76.510619
#                     Shared room       50.527845
# Manhattan           Entire home/apt  249.238211
#                     Private room     116.805594
#                     Shared room       88.977083
# Queens              Entire home/apt  147.050573
#                     Private room      71.776855
#                     Shared room       69.020202
# Staten Island       Entire home/apt  173.846591
#                     Private room      62.292553
#                     Shared room       57.444444

# %% [markdown]
# - Create a new column indicating high-demand area `(availability_365 > 300)`, calculate the revenue for each listing `(revenue = price * minimum_nights)` and display the dataframe.

# %%
if 'high_demand' not in df1.columns:
  df1.insert(df1.shape[1], 'high_demand', df1['availability_365'] > 300)

if 'revenue' not in df1.columns:
  df1.insert(df1.shape[1], 'revenue', df1['price']*df1['minimum_nights'])

df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0
#
#     Z_price  Z_minimum_nights  high_demand  revenue
# 0 -0.015570         -0.300329         True      149
# 1  0.300794         -0.300329         True      225
# 2 -0.011407         -0.200426         True      450
# 3 -0.265330         -0.300329        False       89
# 4 -0.302795          0.149232        False      800

# %% [markdown]
# - Bin the '`price`' column into categories (e.g., budget, moderate, expensive) based on price ranges.

# %%
bins = np.linspace (df1['price'].min(), df1['price'].max(),4)
labels = ['budget','moderate','expensive']

print(bins)

df1['bins'] = pd.cut(df1['price'], bins = bins, labels = labels, include_lowest = True)
display(df1)
# Out:
# [    0.          3333.33333333  6666.66666667 10000.        ]
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# 1           Jennifer           Manhattan             Midtown  40.75362
# 2          Elisabeth           Manhattan              Harlem  40.80902
# 3        LisaRoxanne            Brooklyn        Clinton Hill  40.68514
# 4              Laura           Manhattan         East Harlem  40.79851
# ...              ...                 ...                 ...       ...
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#        longitude        room_type  price  ...  number_of_reviews  last_review  \
# 0      -73.97237     Private room    149  ...                  9   2018-10-19
# 1      -73.98377  Entire home/apt    225  ...                 45   2019-05-21
# 2      -73.94190     Private room    150  ...                  0          NaN
# 3      -73.95976  Entire home/apt     89  ...                270   2019-07-05
# 4      -73.94399  Entire home/apt     80  ...                  9   2018-11-19
# ...          ...              ...    ...  ...                ...          ...
# 48890  -73.94995     Private room     70  ...                  0          NaN
# 48891  -73.93317     Private room     40  ...                  0          NaN
# 48892  -73.94867  Entire home/apt    115  ...                  0          NaN
# 48893  -73.99112      Shared room     55  ...                  0          NaN
# 48894  -73.98933     Private room     90  ...                  0          NaN
#
#       reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                  0.21                               6               365
# 1                  0.38                               2               355
# 2                   NaN                               1               365
# 3                  4.64                               1               194
# 4                  0.10                               1                 0
# ...                 ...                             ...               ...
# 48890               NaN                               2                 9
# 48891               NaN                               2                36
# 48892               NaN                               1                27
# 48893               NaN                               6                 2
# 48894               NaN                               1                23
#
#         Z_price  Z_minimum_nights  high_demand  revenue    bins
# 0     -0.015570         -0.300329         True      149  budget
# 1      0.300794         -0.300329         True      225  budget
# 2     -0.011407         -0.200426         True      450  budget
# 3     -0.265330         -0.300329        False       89  budget
# 4     -0.302795          0.149232        False      800  budget
# ...         ...               ...          ...      ...     ...
# 48890 -0.344421         -0.250377        False      140  budget
# 48891 -0.469302         -0.150475        False      160  budget
# 48892 -0.157101          0.149232        False     1150  budget
# 48893 -0.406862         -0.300329        False       55  budget
# 48894 -0.261168         -0.000622        False      630  budget
#
# [48858 rows x 21 columns]

# %% [markdown]
# - Calculate summary statistics (e.g., mean, median) for the 'price' column based on neighbourhood_group and room_type. Display the summary statistics for '`price`'.

# %%
price_summary = df1.groupby(['neighbourhood_group', 'room_type']).agg({'price':['mean', 'median', 'std']})
display(price_summary)

display(df1['price'].describe())
# Out:
#                                           price
#                                            mean median         std
# neighbourhood_group room_type
# Bronx               Entire home/apt  127.645503  100.0   95.114513
#                     Private room      66.788344   53.5  107.009071
#                     Shared room       58.610169   40.0  102.251046
# Brooklyn            Entire home/apt  178.362609  145.0  226.480672
#                     Private room      76.510619   65.0  124.764826
#                     Shared room       50.527845   36.0   53.444485
# Manhattan           Entire home/apt  249.238211  191.0  331.938262
#                     Private room     116.805594   90.0  190.292709
#                     Shared room       88.977083   69.0   92.416534
# Queens              Entire home/apt  147.050573  120.0  129.383208
#                     Private room      71.776855   60.0  180.559348
#                     Shared room       69.020202   37.0  171.000607
# Staten Island       Entire home/apt  173.846591  100.0  394.600216
#                     Private room      62.292553   50.0   36.138245
#                     Shared room       57.444444   30.0   45.119594
# count    48858.000000
# mean       152.740309
# std        240.232386
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# - Group the data by neighbourhood_group and calculate the average '`availability_365`'. Display the average '`availability_365`' for each '`neighbourhood_group`'.

# %%
average_availability = df1.groupby(['neighbourhood_group']).agg({'availability_365':'mean'})
display(average_availability)
# Out:
#                      availability_365
# neighbourhood_group
# Bronx                      165.704316
# Brooklyn                   100.235801
# Manhattan                  112.013445
# Queens                     144.487288
# Staten Island              199.678284

# %% [markdown]
# ## Part 2- Feature Selection (5 Marks)
# Please perform the following tasks using Dataset2:\
# [Hint: you may refer to lab 6 to use a ready dataset by imputing the missing data with median]

# %% [markdown]
# Perform Feature Selection as follows:
# - Apply a forward selection by using linear regression, set k_features = 4. Record the selected features.
# - Apply a Filter method by using correlation. Select features with correlation > 0.5. Record the selected features.
# - Apply an embedded method by using Lasso Regression. Record the selected features.

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('Dataset2.data', sep=",", header=None)
data.columns=[
    "ID",
    "Clump_Thickness",
    "Uniformity_CellSize",
    "Uniformity_CellShape",
    "Marginal_Adhesion",
    "Single_Epithelial",
    "Bare_Nuclei",
    "Bland_Chromatin", 
    "Normal_Nucleoli", 
    "Mitoses",
    "Classes"
]
print (data.head()) #display the first few rows of data
# Out:
#         ID  Clump_Thickness  Uniformity_CellSize  Uniformity_CellShape  \
# 0  1000025                5                    1                     1
# 1  1002945                5                    4                     4
# 2  1015425                3                    1                     1
# 3  1016277                6                    8                     8
# 4  1017023                4                    1                     1
#
#    Marginal_Adhesion  Single_Epithelial Bare_Nuclei  Bland_Chromatin  \
# 0                  1                  2           1                3
# 1                  5                  7          10                3
# 2                  1                  2           2                3
# 3                  1                  3           4                3
# 4                  3                  2           1                3
#
#    Normal_Nucleoli  Mitoses  Classes
# 0                1        1        2
# 1                2        1        2
# 2                1        1        2
# 3                7        1        2
# 4                1        1        2

# %% [markdown]
# ## Part 3- Data Visualisation (5 Marks)
# Select any TWO numerical variables from Dataset1. Use Pandas to create a histogram to visualise the distribution of each of these variables. Briefly describe each histogram.

# %%
import pandas as pd

df3 = pd.read_csv('Dataset1.csv', header = 0)

# %%
plt.hist(df3['latitude'], color = 'skyblue', ec = 'black')
plt.title('Histogram of Latitude')
plt.xlabel('Values')
plt.ylabel('Frequency')

plt.show()

# %%
plt.hist(df3['price'], color = 'green' , ec = 'black', )
plt.title('Histogram of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.show()
